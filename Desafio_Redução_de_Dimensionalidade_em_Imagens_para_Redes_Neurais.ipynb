# %% [markdown]
# <a href="https://colab.research.google.com/github/wsbrito/DesafiosDIO/blob/main/Desafio_Redu%C3%A7%C3%A3o_de_Dimensionalidade_em_Imagens_para_Redes_Neurais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio - Redução de Dimensionalidade em Imagens para Redes Neurais
# ### Autor: Wagner dos Santos Brito

# %% [markdown]
# Abaixo segue a minha sugestão para o desafio proposto que era utilizar o Python para converter imagens coloridas em tons de cinza e binarizá-la sem a utilização de bibliotecas que contivessem tais recursos

# %% [markdown]
# ## Importações necessárias

# %%
from google.colab import files
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %% [markdown]
# ## Funções auxiliares

# %%
# Função para carregar a imagem a partir do computador do usuário
def carregar_imagem():
  uploaded = files.upload()
  nome_do_arquivo = list(uploaded.keys())[0]
  return nome_do_arquivo

# %%
# Função para converter uma imagem colorida para tons de cinza
def rgb_to_gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
# Função para binarizar uma imagem em tons de cinza
def gray_to_binarize(gray, threshold):
    binary = np.zeros_like(gray)
    binary[gray >= threshold] = 1
    return binary

# %% [markdown]
# ## Implementação do desafio

# %%
# Carregar a imagem (substitua pelo caminho da sua imagem)
img = plt.imread(carregar_imagem())

# Converter para tons de cinza
gray = rgb2gray(img)

# Binarizar (ajuste o threshold conforme necessário)
threshold = 128
binary_img = binarize(gray, threshold)

# Mostrar as imagens
plt.figure(figsize=(15,5))
plt.subplot(1,3,1), plt.imshow(img)
plt.title('Original'), plt.axis('off')
plt.subplot(1,3,2), plt.imshow(gray, cmap='gray')
plt.title('Tons de Cinza'), plt.axis('off')
plt.subplot(1,3,3), plt.imshow(binary_img, cmap='gray')
plt.title('Binarizada'), plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-85b8270c-d017-4283-91a3-1909df630e0d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85b8270c-d017-4283-91a3-1909df630e0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
